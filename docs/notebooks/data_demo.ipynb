# %% [markdown]
# # Scenario Data Loading
#
# This tutorial demonstrates how to load scenario data from the Waymo Open Motion Dataset (WOMD) using the Waymax dataloader.

# %%
# %%capture
import numpy as np
import mediapy
from tqdm import tqdm
import dataclasses

from waymax import config as _config
from waymax import dataloader
from waymax import datatypes
from waymax import visualization

import imageio_ffmpeg
import os
ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()
os.environ["PATH"] += os.pathsep + os.path.dirname(ffmpeg_path)

# %% [markdown]
# We first create a dataset config, using the default configs provided in the `waymax.config` module. In particular, `config.WOD_1_1_0_TRAINING` is a pre-defined configuration that points to version 1.1.0 of the Waymo Open Dataset.
#
# The data config contains a number of options to configure how and where the dataset is loaded from. By default, the `WOD_1_1_0_TRAINING` loads up to 128 objects (e.g. vehicles, pedestrians) per scenario. Here, we can save memory and compute by loading only the first 32 objects stored in the scenario.
#
# We use the `dataloader.simulator_state_generator` function to create an iterator
# through Open Motion Dataset scenarios. Calling next on the iterator will retrieve the first scenario in the dataset.

# %%
config = dataclasses.replace(_config.WOD_1_2_1_TRAIN, max_num_objects=32)
data_iter = dataloader.simulator_state_generator(config=config)
scenario = next(data_iter)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 3
#       1 config = dataclasses.replace(_config.WOD_1_2_1_TRAIN, max_num_objects=32)
#       2 data_iter = dataloader.simulator_state_generator(config=config)
# ----> 3 scenario = next(data_iter)
#
# File ~\Documents\Project\waymax\waymax\dataloader\dataloader_utils.py:229, in get_data_generator(config, preprocess_fn, postprocess_fn)
#     227 else:
#     228   postprocess_fn = jax.jit(postprocess_fn)
# --> 229 for example in dataset.as_numpy_iterator():
#     230   yield postprocess_fn(example)
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4788, in NumpyIterator.__next__(self)
#    4785     numpy.setflags(write=False)
#    4786   return numpy
# -> 4788 return nest.map_structure(to_numpy, next(self._iterator))
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:826, in OwnedIterator.__next__(self)
#     824 def __next__(self):
#     825   try:
# --> 826     return self._next_internal()
#     827   except errors.OutOfRangeError:
#     828     raise StopIteration
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:776, in OwnedIterator._next_internal(self)
#     773 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     774 # to communicate that there is no more data to iterate over.
#     775 with context.execution_mode(context.SYNC):
# --> 776   ret = gen_dataset_ops.iterator_get_next(
#     777       self._iterator_resource,
#     778       output_types=self._flat_output_types,
#     779       output_shapes=self._flat_output_shapes)
#     781   try:
#     782     # Fast path for the case `self._structure` is not a nested structure.
#     783     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3081, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3079 if tld.is_eager:
#    3080   try:
# -> 3081     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3082       _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3083       "output_shapes", output_shapes)
#    3084     return _result
#    3085   except _core._NotOkStatusException as e:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 297: invalid continuation byte

# %% [markdown]
# Next, we can plot the initial state of this scenario. We use a matplotlib-based visualization available in the `waymax.visualization` package.

# %%
# Using logged trajectory
img = visualization.plot_simulator_state(scenario, use_log_traj=True)
mediapy.show_image(img)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="600" height="600" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# The Waymo Open Motion Dataset consists of 9-second trajectory snippets. We can visualize the entire logged trajectory as a video as follows:

# %%
imgs = []

state = scenario
for _ in range(scenario.remaining_timesteps):
  state = datatypes.update_state_by_log(state, num_steps=1)
  imgs.append(visualization.plot_simulator_state(state, use_log_traj=True))



mediapy.show_video(imgs, fps=10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 10
#       5   state = datatypes.update_state_by_log(state, num_steps=1)
#       6   imgs.append(visualization.plot_simulator_state(state, use_log_traj=True))
# ---> 10 mediapy.show_video(imgs, fps=10)
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\mediapy\__init__.py:1869, in show_video(images, title, **kwargs)
#    1846 def show_video(
#    1847     images: Iterable[_NDArray], *, title: str | None = None, **kwargs: Any
#    1848 ) -> str | None:
#    1849   """Displays a video in the IPython notebook and optionally saves it to a file.
#    1850
#    1851   See `show_videos`.
#    (...)
#    1867     html string if `return_html` is `True`.
#    1868   """
# -> 1869   return show_videos([images], [title], **kwargs)
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\mediapy\__init__.py:1951, in show_videos(videos, titles, width, height, downsample, columns, fps, bps, qp, codec, ylabel, html_class, return_html, **kwargs)
#    1949   video = [resize_image(image, (h, w)) for image in video]
#    1950   first_image = video[0]
# -> 1951 data = compress_video(
#    1952     video, metadata=metadata, fps=fps, bps=bps, qp=qp, codec=codec
#    1953 )
#    1954 if title is not None and _config.show_save_dir:
#    1955   suffix = _filename_suffix_from_codec(codec)
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\mediapy\__init__.py:1788, in compress_video(images, codec, **kwargs)
#    1786 with tempfile.TemporaryDirectory() as directory_name:
#    1787   tmp_path = pathlib.Path(directory_name) / f'file{suffix}'
# -> 1788   write_video(tmp_path, images, codec=codec, **kwargs)
#    1789   return tmp_path.read_bytes()
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\mediapy\__init__.py:1758, in write_video(path, images, **kwargs)
#    1756   dtype = np.dtype(np.uint16)
#    1757 kwargs = {'metadata': getattr(images, 'metadata', None), **kwargs}
# -> 1758 with VideoWriter(path, shape=shape, dtype=dtype, **kwargs) as writer:
#    1759   for image in images:
#    1760     writer.add_image(image)
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\mediapy\__init__.py:1578, in VideoWriter.__enter__(self)
#    1577 def __enter__(self) -> 'VideoWriter':
# -> 1578   ffmpeg_path = _get_ffmpeg_path()
#    1579   input_pix_fmt = self._get_pix_fmt(self.dtype, self.input_format)
#    1580   try:
#
# File ~\Documents\Project\waymax\.venv\lib\site-packages\mediapy\__init__.py:1170, in _get_ffmpeg_path()
#    1168 path = _search_for_ffmpeg_path()
#    1169 if not path:
# -> 1170   raise RuntimeError(
#    1171       f"Program '{_config.ffmpeg_name_or_path}' is not found;"
#    1172       " perhaps install ffmpeg using 'apt install ffmpeg'."
#    1173   )
#    1174 return path
#
# RuntimeError: Program 'ffmpeg' is not found; perhaps install ffmpeg using 'apt install ffmpeg'.
